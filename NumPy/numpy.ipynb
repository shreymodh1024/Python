# %%
import numpy as np

# %%
a = np.array([1,2,3,4,5])
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
a.size
# Out:
# 5

# %%
a.ndim
# Out:
# 1

# %%
a.shape
# Out:
# (5,)

# %%
c = np.array([20,2,3,4])
c[1] = 100
c
# Out:
# array([ 20, 100,   3,   4])

# %%
d = c[1:3]
d
# Out:
# array([100,   3])

# %%
z = [1,0] + [0,1]
z
#this was not expected from addition
# Out:
# [1, 0, 0, 1]

# %%
z = np.array([1,0]) + np.array([0,1])
z
#this is what was expected
# Out:
# array([1, 1])

# %%
#an alternative for this is:
u = [1,0]
v = [0,1]
z = []
for n,m in zip(u,v):
    z.append(n+m)
z
#it does not use numpy
# Out:
# [1, 1]

# %%
#array multiplication with scaler
y = [1,2]
2*y
#this was not expected
# Out:
# [1, 2, 1, 2]

# %%
y = np.array([1,2])
2*y
#this was expected
# Out:
# array([2, 4])

# %%
u = [1,2] 
v = [3,4]
u * v
#this was not expected
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 u = [1,2]
#       2 v = [3,4]
# ----> 3 u * v
#       4 u
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
a = np.array([1,2]) * np.array([3,4])
a
#this was expected
# Out:
# array([3, 8])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
u = np.array([1,2])
v = np.array([3,4])
np.dot(u,v) #for dot product
# Out:
# np.int64(11)

# %% [markdown]
# ## Universal functions

# %%
a = np.array([1,-1,1,-1])
a.mean()
# Out:
# np.float64(0.0)

# %%
type(a.mean())
# Out:
# numpy.float64

# %%
x = a.max()
print(x)
print(type(x))
# Out:
# 1
# <class 'numpy.int64'>

# %%
np.pi
# Out:
# 3.141592653589793

# %%
type(np.pi)
# Out:
# float

# %%
x = np.array([0, np.pi/2, np.pi])
x
# Out:
# array([0.        , 1.57079633, 3.14159265])

# %%
y = np.sin(x)
y
# Out:
# array([0.0000000e+00, 1.0000000e+00, 1.2246468e-16])

# %%
type(y[1])
# Out:
# numpy.float64

# %%
z = np.linspace(-2,2,9)
z
# Out:
# array([-2. , -1.5, -1. , -0.5,  0. ,  0.5,  1. ,  1.5,  2. ])

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
np.__version__
# Out:
# '2.4.6'

# %%
plt.plot(x,y)
