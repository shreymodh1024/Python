# %%
fruits = ["apple", "banana", "orange"] 
fruits.append("mango") 
print(fruits)
# Out:
# ['apple', 'banana', 'orange', 'mango']

# %%
list1 = [1,2,3] + [1,1,1]

# %%
list1
# Out:
# [1, 2, 3, 1, 1, 1]

# %%
dictionary = {
    "a":'value1',
    'b': 'value2'
}
dictionary.keys() = {'x','y','z'}
dictionary
# Out:
#   Cell In[10], line 5
#     dictionary.keys() = {'x','y','z'}
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
print(dictionary)
# Out:
# {'a': 'value1', 'b': 'value2'}

# %%
print(dictionary.values())
# Out:
# dict_values(['value1', 'value2'])

# %%
dict1 = {"one", "two", "three"}
dict1
# Out:
# {'one', 'three', 'two'}

# %%
dict1.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 dict1.keys()
#
# AttributeError: 'set' object has no attribute 'keys'

# %%
list(dictionary.keys())
# Out:
# ['a', 'b']

# %%
list1 = ['one', 'two', 'three']
print(list1)
set1 = set(list1)
print(set1)
# Out:
# ['one', 'two', 'three']
# {'three', 'two', 'one'}

# %%
type(set1)
# Out:
# set

# %%
'one' in set1
# Out:
# True

# %%
set1.append('aye')
set1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 set1.append('aye')
#       2 set1
#
# AttributeError: 'set' object has no attribute 'append'

# %%
a = ((1,2),(3,4))

# %%
a[1]
# Out:
# (3, 4)

# %%
a[1][1]
# Out:
# 4

# %%
list1
# Out:
# ['one', 'two', 'three']

# %%
list1.extend(['four', 'five'])
print(list1)
# Out:
# ['one', 'two', 'three', ['four', 'five'], 'four', 'five']

# %%
list1.append('six', 'seven')
list1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 list1.append('six', 'seven')
#       2 list1
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
A=["hard rock",10,1.2]
del(A[1])

# %%
A
# Out:
# ['hard rock', 1.2]

# %%
B = A[:]
B
# Out:
# ['hard rock', 1.2]

# %%
del(A[0])
B
# Out:
# ['hard rock', 1.2]

# %%
A
# Out:
# [1.2]

# %%
len(B)
# Out:
# 2

# %%
a = {1,2,3}
b= {4,5,6}
a + b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 3
#       1 a = {1,2,3}
#       2 b= {4,5,6}
# ----> 3 a + b
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
a | b
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
1=2
# Out:
#   Cell In[45], line 1
#     1=2
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
range(10,15)
# Out:
# range(10, 15)

# %%
list(range(10,15))
# Out:
# [10, 11, 12, 13, 14]

# %%
for i in range(0,5,2):
    print(i)
# Out:
# 0
# 2
# 4

# %%
for i, x in enumerate(['A', 'B', 'C']):
    print(i, x)
# Out:
# 0 A
# 1 B
# 2 C

# %%
x = enumerate(['A', 'B', 'C'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 x = enumerate(['A', 'B', 'C'])(0)
#
# TypeError: 'enumerate' object is not callable

# %%
print(x)
# Out:
# <enumerate object at 0x751a63027c40>

# %%
# Write your code below and press Shift+Enter to execute
def divide(a,b):
    return a/b

a = divide(4,4)
print(a)
# Out:
# 1.0
# hello world

# %%
divide(10,2)
# Out:
# 5.0

# %%
l = [3,2,1]
sorted(l)
# Out:
# [1, 2, 3]

# %%
l
# Out:
# [3, 2, 1]

# %%
l = sorted(l)
l
# Out:
# [1, 2, 3]
