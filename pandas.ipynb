# %%
import pandas as pd

# %%
df = pd.read_csv('sample.csv')

# %%
df
# Out:
#    id            name  age          city                    email
# 0   1      John Smith   28      New York   john.smith@example.com
# 1   2    Emma Johnson   34   Los Angeles       emma.j@example.com
# 2   3   Michael Brown   45       Chicago       mbrown@example.com
# 3   4     Sarah Davis   22       Houston  sarah.davis@example.com
# 4   5    David Wilson   31       Phoenix      dwilson@example.com
# 5   6  Laura Martinez   27  Philadelphia    lmartinez@example.com
# 6   7  James Anderson   39   San Antonio    janderson@example.com
# 7   8   Olivia Taylor   25     San Diego      otaylor@example.com

# %%
df.shape
# Out:
# (8, 5)

# %%
type(df.shape)
# Out:
# tuple

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      8 non-null      int64
#  1   name    8 non-null      str
#  2   age     8 non-null      int64
#  3   city    8 non-null      str
#  4   email   8 non-null      str
# dtypes: int64(2), str(3)
# memory usage: 784.0 bytes

# %%
# Create a Series from a list
data = [10, 20, 30, 40, 50]
s = pd.Series(data)
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
df.head()
# Out:
#    id           name  age         city                    email
# 0   1     John Smith   28     New York   john.smith@example.com
# 1   2   Emma Johnson   34  Los Angeles       emma.j@example.com
# 2   3  Michael Brown   45      Chicago       mbrown@example.com
# 3   4    Sarah Davis   22      Houston  sarah.davis@example.com
# 4   5   David Wilson   31      Phoenix      dwilson@example.com

# %%
s[2]
# Out:
# np.int64(30)

# %%
print(s[2])
# Out:
# 30

# %%
print(s.iloc[3])
# Out:
# 40

# %%
print(s[1:4])
# Out:
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# Creating a DataFrame from a dictionary
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'San Francisco', 'Los Angeles', 'Chicago']
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   28        Chicago

# %%
df.iloc[2]
# Out:
# Name        Charlie
# Age              35
# City    Los Angeles
# Name: 2, dtype: object

# %%
print(df['Name'])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: str

# %%
print(df['City'])
# Out:
# 0         New York
# 1    San Francisco
# 2      Los Angeles
# 3          Chicago
# Name: City, dtype: str

# %%
print(df.iloc[2]) 
print()# Access the third row by position
print(df.loc[1])    # Access the second row by label
# Out:
# Name        Charlie
# Age              35
# City    Los Angeles
# Name: 2, dtype: object
#
# Name              Bob
# Age                30
# City    San Francisco
# Name: 1, dtype: object

# %% [markdown]
# ## In short, you can do anything with data using pandas

# %%
df = pd.read_excel('student_info.xlsx')

# %%
df
# Out:
#     Team No.                   Timestamp                Team Leader Name  \
# 0          1  2026-02-13 11:08:59.553000                       Yug Shah
# 1          2  2026-02-13 11:11:04.628000        BUSA TEERTH NARENDRABHAI
# 2          3  2026-02-13 11:15:16.420000                     Yatri Raval
# 3          4  2026-02-13 11:16:31.414000     Thakkar Pankti Bhaveshkumar
# 4          5  2026-02-13 11:17:05.969000          Choksi khushil brijesh
# ..       ...                         ...                             ...
# 88        89          2/16/2026 11:23:00       Kukadiya Manav Rajeshbhai
# 89        90          2/16/2026 11:23:39          Jay Rajeshbhai Gulvani
# 90        91          2/16/2026 11:24:27          Lukhi Devam Mukeshbhai
# 91        92          2/16/2026 14:02:57      Hetav Brijeshkumar Solanki
# 92        93                         NaN  Momin Munirahbanu zahirahemad.
#
#             Team Leader Email  Team Leader Enrolment Number  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 17 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Team No.                                                                        93 non-null     int64
#  1   Timestamp                                                                       89 non-null     object
#  2   Team Leader Name                                                                93 non-null     str
#  3   Team Leader Email                                                               93 non-null     str
#  4   Team Leader Enrolment Number                                                    93 non-null     int64
#  5   Team Leader  Student Branch                                                     93 non-null     str
# ...

# %%
df[['Team Leader Name', 'Team Leader Email']]
# Out:
#                   Team Leader Name          Team Leader Email
# 0                        Yug Shah     yugshah180907@gmail.com
# 1         BUSA TEERTH NARENDRABHAI       teerth2307@gmail.com
# 2                      Yatri Raval      yatriraval7@gmail.com
# 3      Thakkar Pankti Bhaveshkumar        panktit13@gmail.com
# 4           Choksi khushil brijesh  khushilchoksi77@gmail.com
# ..                             ...                        ...
# 88       Kukadiya Manav Rajeshbhai  manavkukadiya46@gmail.com
# 89          Jay Rajeshbhai Gulvani      jaygulvani4@gmail.com
# 90          Lukhi Devam Mukeshbhai    devamlukhi358@gmail.com
# 91      Hetav Brijeshkumar Solanki  hetavsolanki781@gmail.com
# 92  Momin Munirahbanu zahirahemad.       Pasand3486@gmail.com
#
# [93 rows x 2 columns]

# %%
# Get rows where Name contains 'li' (like Alice or Charlie)
rows = df.loc[df['Team Leader Name'].str.contains('Shrey')]
rows
# Out:
#     Team No.                   Timestamp   Team Leader Name  \
# 39        40  2026-02-13 23:39:29.080000  Shrey Pranav Modh
#
#       Team Leader Email  Team Leader Enrolment Number  \
# 39  modhshrey@gmail.com                  251430131072
#
#    Team Leader  Student Branch Team Leader  Division  Team Leader  Roll No.  \
# 39                         CSE                    D2                     52
#
#    Team Leader  Contact Number  \
# 39                  6354075497
#
#    Internal Guide Name (Selected on DE Portal as per given in shared sheet)  \
# 39                                                KJP
#
#     No. of Team Members  \
# 39                    6
#
#    Team Members Names (Write names of Team member by seperating names with comma)  \
# 39  Dhairya Shankarbhai Gajjar,\nKrish Harneshbhai...
#
#    Team Members Contact No.  (Write Contact numbers of first Team member)  \
# 39  8160318682, 8128320536, 9016860869, 9664843794...
#
# ...

# %%
type(rows)
# Out:
# pandas.DataFrame

# %%
rows.iloc[0,11]
# Out:
# 'Dhairya Shankarbhai Gajjar,\nKrish Harneshbhai Upadhyay, \nShail Chiragkumar Thaker, \nOm Mahesh Patel,\nAnsh Pinakin Patel'
