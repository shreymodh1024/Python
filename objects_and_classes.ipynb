# %%
class circle (object):
# Out:
# he

# %%
class student:
    name = 'raju'
#s1 = student()
print(s1.name)
# Out:
# raju

# %%
class vehicles:
    color = 'white'
    def __init__(self, max_speed, mileage):
        self.max_speed = max_speed
        self.mileage = mileage
        
    def seating_capacity(self, seating_capacity=None):
        self.seating_capacity = seating_capacity

    def display(self):
        print("Information of vehicle is as follows: -->")
        print("colour:", self.color)
        print("max speed:", self.max_speed)
        print("mileage:", self.mileage)
        print("seating capacity:", self.seating_capacity)
    
v1 = vehicles(200,20)
v1.seating_capacity(5)
v2 = vehicles(180,25)
v2.seating_capacity(4)
v1.display()
v2.display()
# Out:
# Information of vehicle is as follows: -->
# colour: white
# max speed: 200
# mileage: 20
# seating capacity: 5
# Information of vehicle is as follows: -->
# colour: white
# max speed: 180
# mileage: 25
# seating capacity: 4

# %%
text = "there upon a red   brown fox once upon"
a = set(text.split())
len(a)
# Out:
# 7

# %%
def scientific_add(*nums): 
    return nums[0] + nums[1]
scientific_add([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 def scientific_add(*nums):
#       2     return nums[0] + nums[1]
# ----> 3 scientific_add([1,2,3])
#
# Cell In[2], line 2, in scientific_add(*nums)
#       1 def scientific_add(*nums):
# ----> 2     return nums[0] + nums[1]
#
# IndexError: tuple index out of range

# %%
scientific_add(1,2,3)
# Out:
# 3

# %%
# Out:
# hey
