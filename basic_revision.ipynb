# %%
a = 2
b = 3
print(a,b)
# Out:
# 2 3

# %%
import sys
sys.version
# Out:
# '3.14.6 | packaged by Anaconda, Inc. | (main, Jul  9 2026, 14:37:38) [GCC 14.3.0]'

# %%
print(sys.version)
# Out:
# 3.14.6 | packaged by Anaconda, Inc. | (main, Jul  9 2026, 14:37:38) [GCC 14.3.0]

# %%
print(type(11), type(2.33))
# Out:
# <class 'int'> <class 'float'>

# %%
type('string')
# Out:
# str

# %%
type(23)
# Out:
# int

# %%
type(32343556.44)
# Out:
# float

# %%
type(int(2))
# Out:
# int

# %%
int(2.33)
# Out:
# 2

# %%
str(3)
# Out:
# '3'

# %%
str(3) + str(3)
# Out:
# '33'

# %%
type(True)
# Out:
# bool

# %%
type(int(True))
# Out:
# int

# %%
int(True)
# Out:
# 1

# %%
str(True)
# Out:
# 'True'

# %%
str(hey)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 str(hey)
#
# NameError: name 'hey' is not defined

# %%
bool(3)
# Out:
# True

# %%
bool(3 == 3)
# Out:
# True

# %%
bool(3 == 4)
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
25//4
# Out:
# 6

# %%
name = 'Michael Jordan'
name[0:len(name):2]
# Out:
# 'McalJra'

# %%
name[:]
# Out:
# 'Michael Jordan'

# %%
name[::2]
# Out:
# 'McalJra'

# %%
name[0:5:2]
# Out:
# 'Mca'

# %%
3 * "Satya Nadelo "
# Out:
# 'Satya Nadelo Satya Nadelo Satya Nadelo '

# %%
a = "new string"
b = a.replace('new', 'old')
print(b, a)
# Out:
# old string new string

# %%
b.find('str')
# Out:
# 4

# %%
print(f"b is {b} \nand a is {a}")
# string interpolation
# Out:
# b is old string
# and a is new string

# %%
a[-1]
# Out:
# 'g'

# %%
x = 2
x = 'hello'
print(x)
# Out:
# hello

# %%
int(False)
# Out:
# 0

# %%
int(True)
# Out:
# 1

# %%
article = 'it is an article'
article.capitalize()
# Out:
# 'It is an article'

# %%
article.title()
# Out:
# 'It Is An Article'

# %%
print("Python is \"awesome\"")
# Out:
# Python is "awesome"
